# %%
import pandas as pd
import numpy as np
import pyodbc
pd.set_option('display.max_colwidth',100)

# %%
dbName = 'J:/ssUseCases/Database6.accdb'
connStr = 'DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=%s;' % dbName
cnxn = pyodbc.connect(connStr)
cur = cnxn.cursor()

# %% [markdown]
# ## Keywords

# %%
query = "Select distinct KeywordValue from DataPull_Keyword"
keyDf = pd.read_sql_query(query,cnxn)
keyDf = keyDf.replace('\n','', regex=True)

# %%
keyDf.head()
# Out:
#             KeywordValue
# 0        - mass shooting
# 1                  Aedes
# 2           B. anthracis
# 3     Bacillus anthracis
# 4  Chlamydia trachomatis

# %%
query = "Select distinct * from DataPull_Keyword where AssociatedID in (select distinct AssociatedID from DataPull_Keyword where KeywordValue like '%influenza%')"

pd.read_sql_query(query,cnxn)
# Out:
#          ID AssociatedID                     KeywordValue Category1 Category2  \
# 0      8742      4784270                         Outbreak      None      None
# 1      8743      4784270       Public health surveillance      None      None
# 2      8744      4784270           Syndromic surveillance      None      None
# 3      8745      4784270                        Influenza      None      None
# 4      8746      4784270             Emergency department      None      None
# 5      8747      4784270        Emergency medical service      None      None
# 6      8748      4784270                            Fever      None      None
# 7      8749      4784270                       Timeliness      None      None
# 8      8763     24058494         Databases, Bibliographic      None      None
# 9      8764     24058494                Disease Outbreaks      None      None
# 10     8765     24058494      Emergency Service, Hospital      None      None
# ...

# %%
#QUERY BANK
# query = "Select distinct * from DataPull_Keyword where AssociatedID in (select distinct AssociatedID from DataPull_Keyword where KeywordValue = 'Haemolysis')"
# query = "Select distinct * from DataPull_Keyword where AssociatedID in (select distinct AssociatedID from DataPull_Keyword where KeywordValue = 'HHWWS')"
# query = "Select distinct * from DataPull_Keyword where AssociatedID in (select distinct AssociatedID from DataPull_Keyword where KeywordValue = 'humic-like substances.')"
# query = "Select distinct * from DataPull_Keyword where AssociatedID in (select distinct AssociatedID from DataPull_Keyword where KeywordValue = 'infodemiology')"
# query = "Select distinct * from DataPull_Keyword where AssociatedID in (select distinct AssociatedID from DataPull_Keyword where KeywordValue = 'information seeking behavior')"
# query = "Select distinct * from DataPull_Keyword where AssociatedID in (select distinct AssociatedID from DataPull_Keyword where KeywordValue = 'infoveillance')"
# query = "Select distinct * from DataPull_Keyword where AssociatedID in (select distinct AssociatedID from DataPull_Keyword where KeywordValue = 'Ixodes')"
# query = "Select distinct * from DataPull_Keyword where AssociatedID in (select distinct AssociatedID from DataPull_Keyword where KeywordValue = 'Macaca mulatta')"
# query = "Select distinct * from DataPull_Keyword where AssociatedID in (select distinct AssociatedID from DataPull_Keyword where KeywordValue = 'nose')"
# query = "Select distinct * from DataPull_Keyword where AssociatedID in (select distinct AssociatedID from DataPull_Keyword where KeywordValue = 'Peat fire')"
# query = "Select distinct * from DataPull_Keyword where AssociatedID in (select distinct AssociatedID from DataPull_Keyword where KeywordValue = 'Phylogeny')"
# query = "Select distinct * from DataPull_Keyword where KeywordValue  = 'CTX-M-15'"
# query = "Select distinct * from DataPull_Keyword where KeywordValue  = 'ELR'"
# query = "Select distinct * from DataPull_Keyword where AssociatedID = '3692777'"
# query = "Select distinct * from DataPull_Keyword where KeywordValue = 'Eutrophication'"
# query = "Select distinct * from DataPull_Keyword where KeywordValue = 'EVD'"
# query = "Select distinct * from DataPull_Keyword where KeywordValue = 'feces'"
# query = "Select distinct * from DataPull_Keyword where KeywordValue = 'FETP'"
# query = "Select distinct * from DataPull_Keyword where AssociatedID = '5483346'"
# query = "Select distinct * from DataPull_Keyword where KeywordValue = 'Haemolysis'"
# query = "Select distinct a.AssociatedID, a.KeywordValue, b.Title from DataPull_Keyword as a inner join DataPull_Title as b on a.AssociatedID = b.AssociatedID where a.KeywordValue = 'FETP'"
# query = "Select distinct * from  DataPull_Title where AssociatedID = '3841359'"
# query = "Select distinct a.AssociatedID, a.KeywordValue, b.Title from DataPull_Keyword as a inner join DataPull_Title as b on a.AssociatedID = b.AssociatedID where a.KeywordValue = 'Macaca mulatta'"
# query = "Select distinct a.AssociatedID, a.KeywordValue, b.Title from DataPull_Keyword as a inner join DataPull_Title as b on a.AssociatedID = b.AssociatedID where a.KeywordValue = 'Madagascar'"
# query = "Select distinct a.AssociatedID, a.KeywordValue, b.Title from DataPull_Keyword as a inner join DataPull_Title as b on a.AssociatedID = b.AssociatedID where a.KeywordValue = 'manning maddux'"
# query = "Select distinct a.AssociatedID, a.KeywordValue, b.Title from DataPull_Keyword as a inner join DataPull_Title as b on a.AssociatedID = b.AssociatedID where a.KeywordValue = 'negation'"
# query = "Select distinct a.AssociatedID, a.KeywordValue, b.Title from DataPull_Keyword as a inner join DataPull_Title as b on a.AssociatedID = b.AssociatedID where a.KeywordValue = 'nose'"
# query = "Select distinct a.AssociatedID, a.KeywordValue, b.Title from DataPull_Keyword as a inner join DataPull_Title as b on a.AssociatedID = b.AssociatedID where a.AssociatedID = '25418838'"
# query = "Select distinct b.AssociatedID,b.Title,b.Journal,a.PubType from DataPull_Detail as a inner join DataPull_Title as b on a.AssociatedID = b.AssociatedID where a.PubType like '%conference%'"

# %%
query = "Select distinct * from  DataPull_Text where AbstractText like '%use case%'"
assocIdDf = pd.read_sql_query(query,cnxn)
# assocIdDf.set_option('display.max_colwidth',100)
assocIdDf.head()
# Out:
#      ID AssociatedID NLMCategory  \
# 0  5960      3111580        None
# 1  6172      2676864        None
# 2  6184      3692877        None
# 3  6403      5302473        None
# 4  6418      4371519        None
#
#                                              Label  \
# 0                                      Conclusions
# 1                                             None
# 2                                      Conclusions
# 3                                             None
# 4  Description of the HIE and Base Infrastructure:
#
#                                                                                           AbstractText
# 0  This study suggests that the choice of codes made by ED staff to record a case of influenza-like...
# 1  In this paper we describe and evaluate a new distributed architecture for clinical decision supp...
# 2  The existing syndromic surveillance systems and substantial research in the area indicate an int...
# ...

# %%
query = "Select distinct Title from  DataPull_Title where Title like '%use case%'"
assocIdDf = pd.read_sql_query(query,cnxn)
assocIdDf.head()
# Out:
#                                                                                                  Title
# 0  Cross-Disciplinary Consultancy to Bridge Public Health Technical Needs and Analytic Developers: ...

# %%
query = "Select distinct a.PullSource, count(b.AssociatedID) as idCount from DataPull_ID as a inner join DataPull_Detail as b on a.PullID = b.PullID group by a.PullSource"
countDf = pd.read_sql_query(query,cnxn)
countDf
# Out:
#   PullSource  idCount
# 0        PMC     5665
# 1     PUBMED     1636

# %%
query = "Select distinct PullQuery,PullSource from DataPull_ID"
pullDf = pd.read_sql_query(query,cnxn)
pd.set_option('display.max_colwidth',100)
pullDf.sort_values(by = 'PullSource')
# Out:
#                                                                                              PullQuery  \
# 0                                      (syndromic+surveillance AND emergency+department) AND west+nile
# 15                                                                          syndromic+surveillance[TI]
# 13                                              syndromic+surveillance AND emergency+department+visits
# 12                                                 syndromic+surveillance AND emergency+department[TI]
# 10                                                     syndromic+surveillance AND emergency+department
# 6                                              syndromic+surveillance AND (emergency+department OR ED)
# 8                                  syndromic+surveillance AND (emergency+department OR emergency+room)
# 4                                    Online J Public Health Inform[TA] AND syndromic+surveillance[ALL]
# ...

# %% [markdown]
# ## Write to Excel

# %%
writer = pd.ExcelWriter('J:/testingSsUseCase/20171017keyWords.xlsx')
keyDf.to_excel(writer)
writer.save()
